# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# 載入加州房價數據
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)  # 特徵數據
df['target'] = data.target  # 添加目標變量（房價中位數）

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   target      20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
from sklearn.model_selection import train_test_split
x = df[["MedInc","HouseAge","AveRooms","AveBedrms","Population","AveOccup","Latitude","Longitude",]]
y = df["target"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
sns.displot(data=df,x=df["target"],kde=True)
plt.show()

# %%
image = df.corr()
plt.figure(figsize=(20,20))
ax = sns.heatmap(image,
            annot=True,
            fmt=".2f",
            linewidths=0.5,
            cmap="coolwarm"
            )

ax.set(xlabel="", ylabel="")
ax.xaxis.tick_top()
plt.show()

# %%
x = df["AveRooms"]
y = df["AveBedrms"]
z = df["target"]
plt.scatter(x,y)
plt.show()

# %%
from sklearn import linear_model
model = linear_model.LinearRegression(fit_intercept=True)
model.fit(x_train,y_train)
model.coef_
y_pred = model.predict(x_train)

# %%
import numpy as np

# %%
plt.scatter(x_train.iloc[:,0], y_train, edgecolors="black", color="blue", linewidths=2)
plt.plot(x_train.iloc[:,0], y_pred, color="red")
plt.xlabel('Feature 0')
plt.ylabel('Target')
plt.title('Regression Line')
plt.show()
