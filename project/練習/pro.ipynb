# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# 載入加州房價數據
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)  # 特徵數據
df['target'] = data.target  # 添加目標變量（房價中位數）

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   target      20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
from sklearn.model_selection import train_test_split
x = df[["MedInc","HouseAge","AveRooms","AveBedrms","Population","AveOccup","Latitude","Longitude",]]
y = df["target"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=87)

# %%
sns.displot(data=df,x=df["target"],kde=True)
plt.show()

# %%
image = df.corr()
plt.figure(figsize=(20,20))
ax = sns.heatmap(image,
            annot=True,
            fmt=".2f",
            linewidths=0.5,
            cmap="coolwarm"
            )

ax.set(xlabel="", ylabel="")
ax.xaxis.tick_top()
plt.show()

# %%
df = df.head(300)
x = df[["AveRooms","AveBedrms"]]
y = df["AveBedrms"]
z = df["target"]
plt.scatter(x,z)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       3 y = df["AveBedrms"]
#       4 z = df["target"]
# ----> 5 plt.scatter(x,z)
#       6 plt.show()
#
# File ~/Desktop/stady_file/MachineLearning/venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Desktop/stady_file/MachineLearning/venv/lib/python3.13/site-packages/matplotlib/pyplot.py:3937, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3917 @_copy_docstring_and_deprecators(Axes.scatter)
#    3918 def scatter(
#    3919     x: float | ArrayLike,
#    (...)   3935     **kwargs,
#    3936 ) -> PathCollection:
# -> 3937     __ret = gca().scatter(
#    3938         x,
#    3939         y,
#    3940         s=s,
#    3941         c=c,
#    3942         marker=marker,
#    3943         cmap=cmap,
#    3944         norm=norm,
#    3945         vmin=vmin,
#    3946         vmax=vmax,
#    3947         alpha=alpha,
#    3948         linewidths=linewidths,
#    3949         edgecolors=edgecolors,
#    3950         colorizer=colorizer,
#    3951         plotnonfinite=plotnonfinite,
#    3952         **({"data": data} if data is not None else {}),
#    3953         **kwargs,
#    3954     )
#    3955     sci(__ret)
#    3956     return __ret
#
# File ~/Desktop/stady_file/MachineLearning/venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Desktop/stady_file/MachineLearning/venv/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/Desktop/stady_file/MachineLearning/venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4930, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4928 y = np.ma.ravel(y)
#    4929 if x.size != y.size:
# -> 4930     raise ValueError("x and y must be the same size")
#    4932 if s is None:
#    4933     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4934          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
